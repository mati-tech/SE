# %% [markdown]
# Регрессия – это зависимость среднего значения какой-либо величины
# от некоторой другой величины или от нескольких других величин. В
# отличие от чисто функциональной зависимости 𝑦 = 𝑓(𝑥), когда каждому
# значению независимой переменной 𝑥 соответствует одно определённое
# значение зависимой переменной у, при регрессионной связи одному и тому
# же значению независимой переменной (фактору) 𝑥 могут соответствовать в
# зависимости от конкретного случая различные значения зависимой
# переменной (отклика) у.
# Изучение регрессии основано на том, что случайные величины Х и 𝑌
# связаны между собой вероятностной зависимостью: при каждом
# конкретном значении 𝑋 = 𝑥 величина 𝑌 является случайной величиной с
# вполне определённым распределением вероятностей. Зависимость
# зависимой переменной – отклика от одной независимой переменной –
# фактора или нескольких факторов называется уравнением регрессии. По
# количеству факторов выделяют парную (однофакторную) и
# множественную (многофакторную) регрессию. Для парной будем
# рассматривать следующие методы регрессии: линейную, показательную,
# экспоненциальную, гиперболическую и параболическую.
# Регрессионный анализ – это раздел математической статистики,
# изучающий регрессионную зависимость между случайными величинами по
# статистическим данным. Цель регрессионного анализа состоит в
# определении общего вида уравнения регрессии, вычислении оценок
# неизвестных параметров, входящих в уравнение регрессии проверке
# статистических гипотез о регрессионной связи.
# Таким образом, регрессионный анализ – набор статистических
# методов исследования влияния одной или нескольких независимых
# переменных 𝑋1, … , 𝑋𝑛 на зависимую переменную 𝑌. Независимые
# переменные иначе называют регрессорами или предикторами, а зависимые
# переменные – критериальными переменными.
# 1.1. Теоретический материал – Линейные регрессионные модели
# Линейная регрессия
# Линейная регрессия (Linear regression) – модель зависимости переменной
# x от одной или нескольких других переменных (факторов, регрессоров,
# независимых переменных) с линейной функцией зависимости. Линейная
# регрессия относится к задаче определения «линии наилучшего соответствия»
# через набор точек данных и стала простым предшественником нелинейных
# методов, которые используют для обучения нейронных сетей.
# Цель линейной регрессии — поиск линии, которая наилучшим образом
# соответствует этим точкам. Напомним, что общее уравнение для прямой есть
# 𝑓 (𝑥) = 𝑏 + 𝑚 ⋅ 𝑥 +, где 𝑚 – наклон линии, а 𝑏 – его сдвиг.
# Функция потерь — метод наименьших квадратов
# Функция потерь – это мера количества ошибок, которые наша линейная
# регрессия делает на наборе данных. Хотя есть разные функции потерь, все они
# вычисляют расстояние между предсказанным значением 𝑦(х) и его
# фактическим значением.
# Одна очень распространенная функция потерь называется средней
# квадратичной ошибкой MSE. Чтобы вычислить MSE, мы просто берем все
# значения ошибок, считаем их квадраты длин и усредняем.
# Задача экраполяции
# Допустим у нас есть много экспериментальных точек. Необходимо через
# них провести кривую, которая как можно ближе проходила к этим точкам. При
# этом необходимо минимизировать среднюю квадратичную ошибку (MSE).
# Для решения данной задачи в Python есть множество библиотек. Самыми
# распостраненными выступают:
# numpy - numpy.linalg.lstsq
# scipy - scipy.linalg (содержит все функции из numpy.linalg плюс часть
# новых функций, которых нет в numpy.linalg).
#
#
# Regression is a statistical technique used to analyze the relationship between a dependent variable (output variable) and one or more independent variables (input variables). The goal of regression is to find a mathematical model that can predict the value of the dependent variable based on the values of the independent variables. The output of a regression analysis is a regression equation that can be used to predict the value of the dependent variable for any given values of the independent variables. Regression is commonly used in various fields such as finance, economics, social sciences, and engineering to make predictions or understand the relationship between variables.

# %% [markdown]
# Regression analysis, is a statistical method used to study the relationship between a dependent variable and one or more independent variables. It explains that regression analysis involves developing an equation that describes how the dependent variable changes as the independent variable(s) change, and that this equation can be used to make predictions about the dependent variable. The passage also describes different types of regression models, such as linear, exponential, and hyperbolic regression, and explains that the goal of regression analysis is to determine the best model to fit the data and estimate the unknown parameters in the equation.
#
# Linear Regression
# Linear regression is a model that describes the relationship between a dependent variable x and one or more independent variables (factors, regressors) with a linear function. Linear regression is used to determine the "line of best fit" through a set of data points and has become a simple predecessor to nonlinear methods that are used to train neural networks.
#
# The goal of linear regression is to find the line that best fits these points. Recall that the general equation for a straight line is 𝑓(𝑥) = 𝑏 + 𝑚 ⋅ 𝑥, where 𝑚 is the slope of the line and 𝑏 is its intercept.
#
# Loss function - mean squared error
# The loss function is a measure of how many errors our linear regression makes on a dataset. Although there are different loss functions, they all calculate the distance between the predicted value 𝑦(𝑥) and its actual value.
#
# One very common loss function is mean squared error (MSE). To calculate MSE, we simply take all the error values, square their lengths, and average them.
#
# Extrapolation problem
# Suppose we have many experimental data points. We need to draw a curve through them that passes as close as possible to these points. At the same time, it is necessary to minimize the mean squared error (MSE).
#
# To solve this problem, there are many libraries in Python. The most common ones are:
#
# numpy - numpy.linalg.lstsq
# scipy - scipy.linalg (contains all the functions from numpy.linalg plus some new functions that are not in numpy.linalg).

# %% [markdown]
# 1-1-1 example:
# Проведем прямую 𝑦 = 𝑚𝑥 + 𝑏 через экспериментальные точки

# %%
import numpy as np 
import matplotlib.pyplot as plt 

x = np.array([0,1,2,3])
y = np.array([-1,0.2,0.9,2.1])

A = np.vstack([x,np.ones(len(x))]).T #it makes an array of x and len of x  and T makes the transpose 
print(A)

m, c = np.linalg.lstsq(A,y, rcond=None)[0] #this will find the coefficient for the m and c to fit the data points 

print ('m:', m,'c:', c)

plt.plot(x,y,'o', label = 'Given data', markersize = 12) 
plt.plot (x,m*x +c , 'r', label= 'linear extrapolation', markersize = 10)
plt.legend() #for drawing some labels or something 
plt.show()
# Out:
# [[0. 1.]
#  [1. 1.]
#  [2. 1.]
#  [3. 1.]]
# m: 0.9999999999999999 c: -0.9499999999999997

# %% [markdown]
# 1-1-2 example:
# Пусть 𝑥, 𝑦 – вектора длиной 𝑛 > 3 (точек > 3). Задача заключается в
# построении эстраполяционного полинома второго порядка (параболы). Таким
# образом, необходимо найти такие коэффициенты поринома 𝑎, 𝑏, 𝑐 по методу
# наименьших квадратов. Данные мтогут быть получены в результате
# измерений. Покажем пример генерации данных случайным образом и
# загрузки их из файла.

# %%
import matplotlib.pyplot as plt
import numpy as np

delta = 1.0

x= np.linspace(-5,5,11)
y = x**2+delta*(np.random.rand(11)-0.5) #this will create a random noise between the values from and it substract it from 0.5 to keep in the center 


x+= delta*(np.random.rand(11)-0.5) #same here to keep the data in the center 


x.tofile('x_data.txt','\n')
y.tofile('y_data.txt','\n')

x = np.fromfile('x_data.txt', float, sep='\n')
y = np.fromfile('y_data.txt', float, sep='\n')

#to save in a file 

print(x)
print(y)

m = np.vstack((x**2,x,np.ones(11))).T #this will create the array for the values of y,x and ones for x**2


s = np.linalg.lstsq(m,y,rcond = None)[0] #this is for finding the regression line 


x_prec= np.linspace(-5,5,101) #for array from -5 to 5 and 101 Therefore, the resulting array will have 101 elements that are evenly spaced between -5 and 5

plt.plot(x,y,'D') #diamond shape marker 

plt.plot(x_prec,s[0]*x_prec**2+s[1]*x_prec+s[2],'-',lw=2) #the x_prec controls the range, and the others are just quadratic form of ax**2+bx+c


plt.grid()
plt.show()
# Out:
# [-4.50956479 -3.73265347 -3.01892006 -1.61607071 -1.24039092 -0.42236571
#   0.53416708  1.61903891  2.80771394  3.66862145  4.67358547]
# [25.38515085 16.3176786   8.60519723  4.18465388  0.98477864 -0.07139295
#   0.98394834  4.18170424  8.96863039 15.88108605 24.69006484]

# %% [markdown]
# 1-1-3 example:
# По данным предыдущего примера постройте эстраполяционного полинома
# третьего порядка

# %%
m = np.vstack((x**3, x**2, x, np.ones(11))).T #here we have the x**3 also 
s = np.linalg.lstsq(m, y, rcond = None)[0] 

x_prec = np.linspace(-5, 5, 101) 
plt.plot(x, y, 'D')
plt.plot(x_prec, s[0] * x_prec**3 + s[1] * x_prec**2 + s[2]*x_prec + s[3], '-', lw=3)
plt.grid()
plt.savefig('poly of 3rd power.png')

# %% [markdown]
# Question:
# Представьте собственные данные и постройте эктраполяцию полиномами
# первой, второй и третьей степени.

# %%
import matplotlib.pyplot as plt
from numpy import *
from numpy.random import *
import matplotlib.pyplot as plt
import numpy as np


#!--------------------------------------------------
#-------------3rd-power-----------------------------
delta = 1.0 #to control the noise of the values 

x= linspace(-5,5,11) # 11 numbers from -5 t0 5
y = x**2+delta*(rand(11)-0.5) 
#here we create a new set of relationship between x and y 
x+= delta*(rand(11)-0.5)

# x.tofile('x_data.txt','\n')
# y.tofile('y_data.txt','\n')
# x = fromfile('x_data.txt', float, sep='\n')
# y = fromfile('y_data.txt', float, sep='\n')

m = vstack((x**3,x**2,x,ones(11))).T #the matrice for x values 
s = np.linalg.lstsq(m,y,rcond = None)[0] #the regression value for each x 
#rcond is the amount of accuracy if 1 most high if 0 most low, if none the computer will choose randomly 
# The lstsq function returns four outputs in the following order:
# The solution x (i.e., the regression coefficients).
# The sum of squared residuals.
# The rank of the coefficient matrix.
# The singular values of the coefficient matrix.
# So, by accessing the first element ([0]) of the output, we are extracting the solution, which in this case corresponds to the regression coefficients.


x_prec= linspace(-5,5,101)
plt.plot(x,y,'D')
plt.plot(x_prec,(s[0]*x_prec**3)+(s[1]*x_prec**2)+(s[2]*x_prec)+s[3],'-',lw=3)
plt.title ('3rd power polynom')
plt.grid()
plt.show()

#!--------------------------------------------------
#-------------2nd-power-----------------------------
delta = 1.0 #to control the noise of the values 

x= linspace(-6,6,11) # 11 numbers from -5 t0 5
y = x**2+delta*(rand(11)-0.5) 
x+= delta*(rand(11)-0.5)


m = vstack((x**2,x,ones(11))).T #the matrice for x values 
s = np.linalg.lstsq(m,y,rcond = None)[0] #the regression value for each x 
#rcond is the amount of accuracy if 1 most high if 0 most low, if none the computer will choose randomly 

x_prec= linspace(-6,6,101)
plt.plot(x,y,'D')
plt.plot(x_prec,(s[0]*x_prec**2)+(s[1]*x_prec)+s[2],'-',lw=3)
plt.title ('2nd power polynom')
plt.grid()
plt.show()

#!--------------------------------------------------
#-------------1st-power-----------------------------
x = np.array([1,3,7,9])
y = np.array([-1,0.5,1,2.8])

A = np.vstack([x,np.ones(len(x))]).T


m,c=np.linalg.lstsq(A,y,rcond=None)[0]
# print(A)
# print(m,c)

plt.plot(x,y,'o',label = 'given data', markersize= 10)

plt.plot(x,m*x+c,'r',label= "extrapolation line")
plt.legend()
plt.title('1 power polynom')
plt.show()

# %% [markdown]
# 1-1-4 example:
# Необходимо проверить гипотезу, что наши точечно заданная функция ложится
# на кривую вида 𝑓(𝑥, 𝑏) = 𝑏0 + 𝑏1𝑒𝑥𝑝(−𝑏2𝑥2)

# %%
import matplotlib.pyplot as plt
import scipy as sp
from numpy import *
from numpy.random import *
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# Define the function to fit
def f(x, b0, b1, b2):
    return b0 + b1 * np.exp(-b2 * (x**2))

# Generate some data points with noise
xdata = np.linspace(0, 5, 50)
beta = (0.25, 0.75, 0.5) # Initial guess for the parameters
y = f(xdata, *beta)
ydata = y + 0.05 * np.random.rand(len(xdata))

# Fit the function to the data using curve_fit
beta_opt, beta_cov = sp.optimize.curve_fit(f, xdata, ydata)

# Compute the linear deviation and the sum of the squared residuals
lin_dev = sum(beta_cov[0])
residuals = ydata - f(xdata, *beta_opt)
fres = sum(residuals**2)

# Plot the results
fig, ax = plt.subplots()
ax.scatter(xdata, ydata)
ax.plot(xdata, y, 'r', lw=2, label='Initial guess')
ax.plot(xdata, f(xdata, *beta_opt), 'b', lw=2, label='Fitted curve')
ax.set_xlim(0, 5)
ax.set_xlabel(r"$x$", fontsize=18)
ax.set_ylabel(r"$f(x,\beta)$", fontsize=18)
ax.legend(fontsize=14)

plt.show()

print(xdata)
print(ydata)



# The code generates some data points with noise, fits 
# a function to the data using curve_fit from the scipy.optimize
# module, computes the linear deviation and the sum of the 
# squared residuals, and plots the results. The function being
# fitted is defined by the f function, which takes three
# parameters (b0, b1, b2) and returns a value for each x value
# passed to it. The initial guess for the parameters is given
# by the beta tuple, which is used as the starting point for
# the optimization algorithm used by curve_fit. Finally, the 
# xdata and ydata arrays are printed to the console.
# Out:
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]
# [1.04386737 1.0131526  1.01649966 0.98040098 0.9412101  0.94287737
#  0.89057681 0.83674291 0.83599706 0.78198486 0.72531661 0.68059978
#  0.61255468 0.60523242 0.52456211 0.50790225 0.47506922 0.4447602
#  0.39017827 0.39436721 0.3547338  0.34854025 0.32961449 0.31881373
#  0.31514265 0.31274771 0.28427388 0.29068453 0.28545233 0.28411603
#  0.30017818 0.26365154 0.2625614  0.3019023  0.29362098 0.25675827
# ...

# %% [markdown]
# Необходимо проверить гипотезу, что наши точечно заданная функция ложится
# на кривые вида:
# 1) 𝑓(𝑥, 𝑏) = 𝑏0 + 𝑏1𝑥
# 2) 𝑓(𝑥, 𝑏) = 𝑏0 + 𝑏1𝑥 + 𝑏2**𝑥2
# 3) 𝑓(𝑥, 𝑏) = 𝑏0 + 𝑏1𝑙𝑛(𝑥)
# 4) 𝑓(𝑥, 𝑏) = 𝑏0 𝑥**𝑏1

# %%
import matplotlib.pyplot as plt
import scipy as sp
from numpy import *
from numpy.random import *
import matplotlib.pyplot as plt
import numpy as np
from  scipy.optimize import  curve_fit

# _____________________________1______________________________
beta = (0.25,0.75)

def f(x,b0,b1):
    return b0 + b1*x

xdata = np.linspace(0,5,50)

y = f(xdata, *beta)

ydata = y + 0.05 * np.random.rand(len(xdata))

beta_opt, beta_cov = sp.optimize.curve_fit(f,xdata,ydata)


# beta_opt is a NumPy array that contains the optimized values of the parameters (coefficients) b0 and b1 that minimize the sum of squares of the residuals between the observed data ydata and the fitted curve f(xdata, *beta_opt).

# beta_cov is the estimated covariance matrix of beta_opt. 
# It provides a measure of the uncertainty of the estimated 
# parameters. The diagonal elements of beta_cov represent the
# variance of the corresponding parameter estimates, while the
# off-diagonal elements represent the covariances between the
# parameter estimates.

lin_dev = sum(beta_cov[0])
print(beta_opt)

residuals = ydata -f(xdata, *beta_opt)
fres = sum(residuals**2)
print(fres)

# lin_dev = sum(beta_cov[0]) calculates the linear deviation,
# which is the sum of the diagonal elements of the covariance
# matrix beta_cov obtained from the curve_fit function. The diagonal elements of this matrix represent the variances of the estimated parameters beta_opt.

# residuals = ydata -f(xdata, *beta_opt) computes the 
# residuals, which are the differences between the observed 
# ydata values and the values predicted by the fitted curve 
# evaluated at xdata using the estimated parameters beta_opt.

# fres = sum(residuals**2) calculates the sum of squared
# residuals, which is a measure of the goodness of fit of 
# the curve. A smaller value of the sum of squared residuals
# indicates a better fit.



fig,ax = plt.subplots()
ax.scatter(xdata,ydata)

ax.plot(xdata,y,'r',lw =2 )
ax.plot(xdata,f(xdata,*beta_opt),'b',lw = 2)

ax.set_xlim(0,5)
ax.set_xlabel(r"$x$", fontsize = 18)
ax.set_ylabel(r"$f(x,\beta)$", fontsize = 18)
plt.title('x')
plt.show()

# _____________________________2______________________________

# Define the function f(x,b0,b1,b2) with three parameters
def f(x, b0, b1, b2):
    return b0 + b1 * x + b2 * x**2

# Define the true parameters beta and generate data from f(x,beta)
beta = (0.25, 0.75, 0.5)
xdata = np.linspace(0, 5, 50)
y = f(xdata, *beta)

# Add some random noise to the data
ydata = y + 0.05 * np.random.rand(len(xdata))

# Use curve_fit to find the optimal parameters beta_opt and the covariance matrix beta_cov
beta_opt, beta_cov = curve_fit(f, xdata, ydata)

# Calculate the sum of the diagonal elements of the covariance matrix to get the linear deviation
lin_dev = np.sum(beta_cov.diagonal())

# Print the optimal parameters and the linear deviation
print("Optimal parameters:", beta_opt)
print("Linear deviation:", lin_dev)

# Calculate the residuals and the sum of squared residuals
residuals = ydata - f(xdata, *beta_opt)
fres = np.sum(residuals**2)

# Print the sum of squared residuals
print("Sum of squared residuals:", fres)

# Plot the data points and the true function f(x,beta) in red
# Plot the fitted function f(x,beta_opt) in blue
fig, ax = plt.subplots()
ax.scatter(xdata, ydata)
ax.plot(xdata, y, 'r', lw=2)
ax.plot(xdata, f(xdata, *beta_opt), 'b', lw=2)
ax.set_xlim(0, 5)
ax.set_xlabel(r"$x$", fontsize=18)
ax.set_ylabel(r"$f(x,\beta)$", fontsize=18)
plt.title('x**2')
plt.show()


# _____________________________3______________________________


# Define the true function parameters and the function
beta = (1,2)
def f(x,b0,b1):
    return b0 + b1*np.log(x)

# Generate some noisy data
xdata = np.linspace(1,5,50)
y = f(xdata, *beta)
ydata = y + 0.05 * np.random.rand(len(xdata))

# Fit the curve using scipy.optimize.curve_fit
beta_opt, beta_cov = sp.optimize.curve_fit(f,xdata,ydata)

# Calculate the linear deviation
lin_dev = sum(beta_cov[0])

# Print the optimized parameters and the sum of the residuals squared
print(beta_opt)
residuals = ydata -f(xdata, *beta_opt)
fres = sum(residuals**2)
print(fres)

# Create a plot of the data and the fitted curve
fig,ax = plt.subplots()
ax.scatter(xdata,ydata)
ax.plot(xdata,y,'r',lw =2 )
ax.plot(xdata,f(xdata,*beta_opt),'b',lw = 2)
ax.set_xlim(0,5)
ax.set_xlabel(r"$x$", fontsize = 18)
ax.set_ylabel(r"$f(x,\beta)$", fontsize = 18)
plt.title('ln(x)')
plt.show()


# _____________________________4______________________________

# Define initial parameters
beta = (1,2)

# Define the function we want to fit to the data
def f(x,b0,b1):
    return b0 * x **b1

# Generate some test data for fitting
xdata = np.linspace(1,5,50)
y = f(xdata, *beta)
ydata = y + 0.05 * np.random.rand(len(xdata))

# Fit the function to the data
beta_opt, beta_cov = sp.optimize.curve_fit(f,xdata,ydata)

# Calculate the sum of the diagonal elements of the covariance matrix
# to estimate the linear deviation of the fit
lin_dev = sum(beta_cov[0])

# Print the optimized parameters and the residual sum of squares
print(beta_opt)
residuals = ydata -f(xdata, *beta_opt)
fres = sum(residuals**2)
print(fres)

# Plot the data and the fit
fig,ax = plt.subplots()
ax.scatter(xdata,ydata)
ax.plot(xdata,y,'r',lw =2 )
ax.plot(xdata,f(xdata,*beta_opt),'b',lw = 2)
ax.set_xlim(0,5)
ax.set_xlabel(r"$x$", fontsize = 18)
ax.set_ylabel(r"$f(x,\beta)$", fontsize = 18)
plt.title('x**b1')
plt.show()


# The two printed values before the graph are:

# beta_opt: This is a NumPy array containing the optimal values of the parameters b0 and b1 that minimize the sum of the squared residuals between the predicted and actual y values. These values are obtained by fitting the function f(x,b0,b1) to the data using the curve_fit function from the scipy.optimize module.
# 
# fres: This is a scalar value representing the sum of the squared residuals between the predicted and actual y values. It is computed using the optimal values of b0 and b1 obtained from the curve_fit function. This value is an indicator of how well the model fits the data, with lower values indicating a better fit.
# Out:
# [0.27381729 0.75033894]
# 0.009035005651217544
# Optimal parameters: [0.27986414 0.74470382 0.50108173]
# Linear deviation: 7.933141157064363e-05
# Sum of squared residuals: 0.011875620740116971
# [1.01436517 2.01082116]
# 0.008261838796247499
# [1.00718944 1.9959874 ]
# 0.013067716494565567

# %% [markdown]
# exercise:
# Подставьте собственные данные и поэкспериментируйте с представленными
# функциями. Проанализируйте динамику изменения данных.

# %%
import matplotlib.pyplot as plt
import scipy as sp
import numpy as np
from scipy.optimize import curve_fit

# Define true values of beta
beta = (0.5, 1)

# Define function f(x) using beta parameters
def f(x, b0, b1):
    return b0 + b1*x

# Create an array of x values
xdata = np.linspace(0, 5, 50)

# Evaluate the function f(x) with true beta parameters to get y values
y = f(xdata, *beta)

# Add some noise to the y values to simulate experimental data
ydata = y + 0.05 * np.random.rand(len(xdata))

# Fit the experimental data to the function f(x) using curve_fit from SciPy
beta_opt, beta_cov = sp.optimize.curve_fit(f, xdata, ydata)

# Calculate the linear deviation of the fitted parameters beta_opt
lin_dev = sum(beta_cov[0])

# Print the fitted beta parameters
print(beta_opt)

# Calculate the sum of squared residuals between the fitted curve and the data
residuals = ydata - f(xdata, *beta_opt)
fres = sum(residuals**2)
print(fres)

# Create a figure and axis object to plot the data and fitted curve
fig, ax = plt.subplots()

# Scatter plot of the experimental data points
ax.scatter(xdata, ydata)

# Plot the true function f(x) with red color and linewidth of 2
ax.plot(xdata, y, 'r', lw=2)

# Plot the fitted curve with blue color and linewidth of 2
ax.plot(xdata, f(xdata, *beta_opt), 'b', lw=2)

# Set the x-axis and y-axis limits and labels
ax.set_xlim(0, 5)
ax.set_xlabel(r"$x$", fontsize=18)
ax.set_ylabel(r"$f(x,\beta)$", fontsize=18)

# Display the plot
plt.title('f = b0 + b1*x')
plt.show()


# ________________________________________________________________-
beta = (0.5,0.75,1)

def f(x,b0,b1,b2):
    return b0 + b1*x+b2*x*x

xdata = np.linspace(0,5,50)

y = f(xdata, *beta)

ydata = y + 0.05 * np.random.rand(len(xdata))

beta_opt, beta_cov = sp.optimize.curve_fit(f,xdata,ydata)

lin_dev = sum(beta_cov[0])
print(beta_opt)

residuals = ydata -f(xdata, *beta_opt)
fres = sum(residuals**2)
print(fres)

fig,ax = plt.subplots()
ax.scatter(xdata,ydata)

ax.plot(xdata,y,'r',lw =2 )
ax.plot(xdata,f(xdata,*beta_opt),'b',lw = 2)

ax.set_xlim(0,5)
ax.set_xlabel(r"$x$", fontsize = 18)
ax.set_ylabel(r"$f(x,\beta)$", fontsize = 18)
plt.title('f = b0 + b1*x +b2*x*x')
plt.show()


# ______________________________________________________________

beta = (2,4)

def f(x,b0,b1):
    return b0 + b1*np.log(x)

xdata = np.linspace(3,10,70)

y = f(xdata, *beta)

ydata = y + 0.05 * np.random.rand(len(xdata))

beta_opt, beta_cov = sp.optimize.curve_fit(f,xdata,ydata)

lin_dev = sum(beta_cov[0])
print(beta_opt)

residuals = ydata -f(xdata, *beta_opt)
fres = sum(residuals**2)
print(fres)

fig,ax = plt.subplots()
ax.scatter(xdata,ydata)

ax.plot(xdata,y,'r',lw =2 )
ax.plot(xdata,f(xdata,*beta_opt),'b',lw = 2)

ax.set_xlim(0,5)
ax.set_xlabel(r"$x$", fontsize = 18)
ax.set_ylabel(r"$f(x,\beta)$", fontsize = 18)
plt.title('f = b0 + b1*np.log(x)')
plt.show()
# ___________________________________________________________
beta = (2,3)

def f(x,b0,b1):
    return b0 * x **b1

xdata = np.linspace(2,6,50)

y = f(xdata, *beta)

ydata = y + 0.09 * np.random.rand(len(xdata))

beta_opt, beta_cov = sp.optimize.curve_fit(f,xdata,ydata)

lin_dev = sum(beta_cov[0])
print(beta_opt)

residuals = ydata -f(xdata, *beta_opt)
fres = sum(residuals**2)
print(fres)

fig,ax = plt.subplots()
ax.scatter(xdata,ydata)

ax.plot(xdata,y,'r',lw =2 )
ax.plot(xdata,f(xdata,*beta_opt),'b',lw = 2)

ax.set_xlim(0,5)
ax.set_xlabel(r"$x$", fontsize = 18)
ax.set_ylabel(r"$f(x,\beta)$", fontsize = 18)
plt.title('f = b0 * x **b1')
plt.show()
# Out:
# [0.53378867 0.99722494]
# 0.008826184581641834
# [0.5139214  0.75947608 0.99821741]
# 0.008243553567012774
# [2.02094692 4.00123657]
# 0.014512544163243766
# [2.00356999 2.9990241 ]
# 0.047611679713840505

# %% [markdown]
# Линейная регрессия - это широко используемый метод статистического
# анализа, который использует регрессионный анализ в математической
# статистике для определения количественной взаимосвязи между двумя или
# более переменными. Если регрессионный анализ включает две или более
# независимых переменных, а связь между зависимой и независимой
# переменными является линейной, тогда имееи дело с множественной линейной
# регрессией.
# В этом разделе мы увидим, как библиотеку Scikit-Learn в Python для машинного
# обучения можно использовать для реализации функций регрессии. Мы начнем
# с простой линейной регрессии с участием двух переменных, а затем перейдем к
# линейной регрессии с участием нескольких переменных

# %% [markdown]
# 1-2-1 example:
# Построим простую линейную регрессию в Python с использованием
# библиотеки scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame,Series
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

my_dict = {'Учебное время':[0.50,0.75,1.00,1.25,1.50,1.75,1.75,2.00,2.25,2.50,2.75,3.00,3.25,3.50,4.00,4.25,4.50,4.75,5.00,5.50],
           "Оценка":[10,22,13,43,20,22,33,50,62,48,55,75,62,73,81,76,64,82,90,93]}



dataset = pd.DataFrame(my_dict)

print(dataset.head())

print(dataset.shape)
print(dataset.describe())

plt.scatter(dataset["Учебное время"],dataset['Оценка'],color ='b',label = "данные экзамена")

plt.xlabel("Часы")
plt.ylabel("Оценка")
plt.show()

X =dataset.iloc[:,:-1].values
y = dataset.iloc[:,1].values

print(X)
print(y)

X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.2,random_state=0)

regressorr = LinearRegression()

regressorr.fit(X_train, y_train)
print(regressorr.intercept_)
print(regressorr.coef_)
# Out:
#    Учебное время  Оценка
# 0           0.50      10
# 1           0.75      22
# 2           1.00      13
# 3           1.25      43
# 4           1.50      20
# (20, 2)
#        Учебное время     Оценка
# count      20.000000  20.000000
# mean        2.787500  53.700000
# std         1.507165  26.435821
# min         0.500000  10.000000
# 25%         1.687500  30.250000
# 50%         2.625000  58.500000
# 75%         4.062500  75.250000
# max         5.500000  93.000000
# [[0.5 ]
#  [0.75]
#  [1.  ]
#  [1.25]
#  [1.5 ]
#  [1.75]
#  [1.75]
#  [2.  ]
#  [2.25]
#  [2.5 ]
#  [2.75]
#  [3.  ]
#  [3.25]
#  [3.5 ]
#  [4.  ]
#  [4.25]
#  [4.5 ]
#  [4.75]
#  [5.  ]
#  [5.5 ]]
# [10 22 13 43 20 22 33 50 62 48 55 75 62 73 81 76 64 82 90 93]
# 11.564766839378237
# [15.64766839]

# %% [markdown]
# Получившийся результат можно интерпретировать следующим образом: с
# каждым затраченным часом на обучение результат экзамена повышается
# приблизительно на 17 баллов. Далее можно построить прогнозы. Для этого мы
# будем использовать наши тестовые данные и посмотрим, насколько точно наш
# алгоритм предсказывает процентную оценку. Чтобы сделать прогноз на
# тестовых данных необходимо выполнить следующий код:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame,Series
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

my_dict = {'Учебное время':[0.50,0.75,1.00,1.25,1.50,1.75,1.75,2.00,2.25,2.50,2.75,3.00,3.25,3.50,4.00,4.25,4.50,4.75,5.00,5.50],
           "Оценка":[10,22,13,43,20,22,33,50,62,48,55,75,62,73,81,76,64,82,90,93]}



dataset = pd.DataFrame(my_dict)

print(dataset.head())

print(dataset.shape)
print(dataset.describe())

plt.scatter(dataset["Учебное время"],dataset['Оценка'],color ='b',label = "данные экзамена")

plt.xlabel("Часы")
plt.ylabel("Оценка")
plt.show()

X =dataset.iloc[:,:-1].values
y = dataset.iloc[:,1].values

print(X)
print(y)

X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.2,random_state=0)

regressor = LinearRegression()

regressor.fit(X_train, y_train)
print(regressor.intercept_)
print(regressor.coef_)

y_pred =regressor.predict(X_test)

df = pd.DataFrame({'Actual': y_test,"Predicted": y_pred})


df.plot(kind = 'bar')
plt.grid(which='major', linestyle = '-', linewidth ='0.5', color = 'green')
plt.grid(which='minor', linestyle = ':', linewidth ='0.5', color = 'black')
plt.show()

plt.scatter(X_test,y_test,color = 'gray')
plt.plot(X_test,y_pred,color = 'red', linewidth= 2)
plt.show()
print(df)
# Out:
#    Учебное время  Оценка
# 0           0.50      10
# 1           0.75      22
# 2           1.00      13
# 3           1.25      43
# 4           1.50      20
# (20, 2)
#        Учебное время     Оценка
# count      20.000000  20.000000
# mean        2.787500  53.700000
# std         1.507165  26.435821
# min         0.500000  10.000000
# 25%         1.687500  30.250000
# 50%         2.625000  58.500000
# 75%         4.062500  75.250000
# max         5.500000  93.000000
# [[0.5 ]
#  [0.75]
#  [1.  ]
#  [1.25]
#  [1.5 ]
#  [1.75]
#  [1.75]
#  [2.  ]
#  [2.25]
#  [2.5 ]
#  [2.75]
#  [3.  ]
#  [3.25]
#  [3.5 ]
#  [4.  ]
#  [4.25]
#  [4.5 ]
#  [4.75]
#  [5.  ]
#  [5.5 ]]
# [10 22 13 43 20 22 33 50 62 48 55 75 62 73 81 76 64 82 90 93]
# 11.564766839378237
# [15.64766839]
#     Actual  Predicted
# 0       90  89.803109
# 1       22  23.300518
# 2       93  97.626943
# 3       62  46.772021
# 4       55  54.595855
# 5       82  85.891192
# 6       33  38.948187
# 7       73  66.331606
# ...

# %% [markdown]
# Постройте модель линейной регрессии для произвольных данных из двух
# столбцов. Для примера можно взять точечную зависимость заработной платы от
# опыта работы:
# (https://raw.githubusercontent.com/AnnaShestova/salary-years-simple-linearregression/master/Salary_Data.csv).
# Найдите коэффициенты линии регрессии. Постройте прогноз.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame,Series
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

url = "https://raw.githubusercontent.com/AnnaShestova/salary-years-simple-linear-regression/master/Salary_Data.csv"

df = pd.read_csv(url)


print(df)

print(df.shape)

print(df.describe())

plt.scatter(df['YearsExperience'],df["Salary"],color = 'r',label = "Salary data ")

plt.xlabel("YearsExperience")
plt.ylabel("Salary")

plt.show()

X =df.iloc[:,:-1].values
y = df.iloc[:,1].values

print(X)
print(y)

X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.2,random_state=0)

regressor = LinearRegression()
print("regressor", regressor)

regressor.fit(X_train, y_train)
print("regressor.intercept_",regressor.intercept_ )
print("regressor.coef_", regressor.coef_)

y_pred =regressor.predict(X_test)

df = pd.DataFrame({'Actual': y_test,"Predicted": y_pred})


df.plot(kind = 'bar')
plt.grid(which='major', linestyle = '-', linewidth ='0.5', color = 'green')
plt.grid(which='minor', linestyle = ':', linewidth ='0.5', color = 'black')
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.show()

plt.scatter(X_test,y_test,color = 'gray')
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.plot(X_test,y_pred,color = 'red', linewidth= 2)
plt.title('Table of relationship between yearsExperience and Salary')
plt.show()
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0
# ...

# %% [markdown]
# В предыдущем примере мы проиллюстрировали линейную регрессию
# с двумя переменными. Однако, почти все реальные задачи имеют больше
# параметров. Линейная регрессия с участием нескольких переменных
# называется «множественной линейной регрессией» или многомерной
# линейной регрессией. Шаги для выполнения множественной линейной
# регрессии аналогичны шагам для простой . Разница заключается в оценке.
# Вы можете использовать множественную регрессию, чтобы узнать, какой
# фактор оказывает наибольшее влияние на прогнозируемый результат или
# как различные переменные связаны друг с другом.

# %% [markdown]
# 1-3-1:
# Для решения задачи множественной регрессии можно задействовать уже
# известный метод numpy.linalg.lstsq.

# %%
import numpy as np

y = [1,2,3,4,3,4,5,3,5,5,4,5,4,5,4,5,6,0,6,3,1,3,1]
X = [[0,2,4,1,5,4,5,9,9,9,3,7,8,8,6,6,5,5,5,6,6,5,5],
     [4,1,2,3,4,5,6,7,5,8,7,8,7,8,7,8,6,8,9,2,1,5,6],
     [4,1,2,5,6,7,8,9,7,8,7,8,4,4,3,1,2,3,4,1,3,9,7]]


X =np.transpose(X)
X = np.c_[X,np.ones(X.shape[0])]
linreg = np.linalg.lstsq(X,y,rcond=None)[0]

# multiple regression means that we are modeling the relationship between a dependent variable and multiple independent variables, using a linear equation. It is called "multiple" because there are multiple independent variables, not because we have multiple regression lines. The regression equation in multiple regression has the form:

# y = b0 + b1x1 + b2x2 + ... + bn*xn

# where y is the dependent variable, x1, x2, ..., xn are the 
# independent variables, and b0, b1, b2, ..., bn are the 
# coefficients of the equation. The goal of multiple regression 
# is to find the values of the coefficients that best fit the 
# data, so we can use the equation to make predictions about
# the dependent variable based on the independent variables.
# b0 + b1x1 + b2x2 + ... + bn*xn
print(linreg)
# Out:
# [ 0.13099364  0.26625828 -0.02194925  1.50231509]

# %% [markdown]
# 1-3-2 example:
# Для данных из предыдущей задачи построить модель множественной
# линейной регрессии с использованием средств библиотеки sсikit-learn.

# %%
import matplotlib.pyplot as plt
import seaborn as seabornInstance

from  sklearn.model_selection import train_test_split
from  sklearn.linear_model import LinearRegression
from  sklearn import metrics

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame,Series
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# In this code, we are performing linear regression on a dataset with 
# three independent variables (x1, x2, x3) and one dependent variable (y).

# First, we create two dataframes (df1 and df2) from the lists of x 
# and y values. We then concatenate these dataframes into a single dataset 
# using the pandas concat() function, which we assign to the variable 
# 'dataset'.
# 
# We then split the dataset into training and testing sets using the 
# train_test_split() function from scikit-learn. We assign 20% of the data 
# to the testing set and the remaining 80% to the training set.

# Next, we create a LinearRegression object and fit it to the training
# data using the fit() method. We then use the coefficients of the regression to create a dataframe that shows the impact of each independent variable on the dependent variable.

# Finally, we make predictions using the test data and calculate the 
# mean squared error between the predicted values and the actual values 
# using the mean_squared_error() function from scikit-learn.

y = [1,2,3,4,3,4,5,3,5,5,4,5,4,5,4,5,6,0,6,3,1,3,1]
X = [[0,2,4,1,5,4,5,9,9,9,3,7,8,8,6,6,5,5,5,6,6,5,5],
     [4,1,2,3,4,5,6,7,5,8,7,8,7,8,7,8,6,8,9,2,1,5,6],
     [4,1,2,5,6,7,8,9,7,8,7,8,4,4,3,1,2,3,4,1,3,9,7]]


new_y = np.array(y)
new_y = new_y.transpose()
df1 = pd.DataFrame(new_y)


new_X = np.array(X)
new_X = new_X.transpose()

df2 = pd.DataFrame(new_X)

df1 = df1.rename(columns={0:'y'}, inplace= False)
df2 = df2.rename(columns={0:'x1',1:'x2',2:'x3'},inplace= False)

frames = [df1,df2]


dataset = pd.concat([df1,df2], axis=1,join="inner")
dataset.head()


print(dataset.head())

print(dataset.shape)
dataset.describe()

X= dataset[['x1','x2','x3']]
y = dataset['y']

X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.2,random_state=0)

regressor = LinearRegression()
regressor.fit(X_train,y_train)

coeff_df =  pd.DataFrame(regressor.coef_,X.columns, columns=["Coefficient"])
print(coeff_df)

y_pred = regressor.predict(X_test)

df = pd.DataFrame({"Actual":y_test,'Predicted':y_pred})
print(df)

print("Mean Squared Error:", metrics.mean_squared_error(y_test,y_pred))
# Out:
#    y  x1  x2  x3
# 0  1   0   4   4
# 1  2   2   1   1
# 2  3   4   2   2
# 3  4   1   3   5
# 4  3   5   4   6
# (23, 4)
#     Coefficient
# x1     1.894737
# x2    -4.052632
# x3    -2.947368
#     Actual  Predicted
# 11       5 -13.736842
# 10       4 -14.315789
# 21       3  -8.315789
# 14       4   3.157895
# 20       1  27.473684
# 1        2  25.789474
# 13       5  -0.052632
# 22       1  -6.473684
# 16       6   8.263158
# 8        5   5.157895
# 6        5  -9.421053
# 17       0  -2.789474
# 4        3   4.578947
# 2        3  22.578947
# 5        4  -4.315789
# 18       6  -9.789474
# 9        5  -9.947368
# 7        3  -8.842105
# 19       3  29.315789
# Mean Squared Error: 218.14929289983965

# %% [markdown]
# exercise:
# Постройте модель множественной линейной регрессии для произвольных
# данных из нескольких столбцов. Для примера можно взять потребления
# газа (в миллионах галлонов) в 48 штатах США или набор данных о
# качестве красного вина (1) и (2) соответственно. Найдите коэффициенты
# множественной регрессии. Постройте прогноз.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# In this code, you are reading two different CSV files from GitHub
# URLs using Pandas read_csv function. Then, you are splitting the 
# datasets into training and testing sets using train_test_split 
# function from scikit-learn library. After that, you are fitting 
# separate linear regression models using the training sets for each 
# dataset and making predictions on the testing sets using the predict
# method of each model. Finally, you are calculating and printing the mean 
# squared error for
# each model using the mean_squared_error function from scikit-learn.

url1 = 'https://raw.githubusercontent.com/likarajo/petrol_consumption/master/data/petrol_consumption.csv'
url2 = 'https://raw.githubusercontent.com/aniruddhachoudhury/Red-Wine-Quality/master/winequality-red.csv'

dataset1 = pd.read_csv(url1)
dataset2 = pd.read_csv(url2)

X_train1, X_test1, y_train1, y_test1 = train_test_split(dataset1.iloc[:, :-1],
                                                        dataset1.iloc[:, -1],
                                                        test_size=0.8,
                                                        random_state=0)

X_train2, X_test2, y_train2, y_test2 = train_test_split(dataset2.iloc[:, :-1],
                                                        dataset2.iloc[:, -1],
                                                        test_size=0.8,
                                                        random_state=0)

regressor1 = LinearRegression()
regressor1.fit(X_train1, y_train1)

regressor2 = LinearRegression()
regressor2.fit(X_train2, y_train2)

y_pred1 = regressor1.predict(X_test1)
df1 = pd.DataFrame({'Actual': y_test1, 'Predicted': y_pred1})
display(df1)

y_pred2 = regressor2.predict(X_test2)
df2 = pd.DataFrame({'Actual': y_test2, 'Predicted': y_pred2})
display(df2)

print('Mean Squared Error first csv: ', metrics.mean_squared_error(y_test1, y_pred1))
print('Mean Squared Error second csv: ', metrics.mean_squared_error(y_test2, y_pred2))
# The mean squared error (MSE) indicates the average 
# squared difference between the predicted and actual values.
# A high MSE value indicates that the model is not able to accurately 
# predict the outcome, whereas a low MSE value indicates
# a good fit of the model to the data.
# Out:
#     Actual   Predicted
# 29     534  448.685954
# 4      410  558.517714
# 26     577  688.732905
# 30     571  647.224286
# 32     577  821.371901
# 37     704  748.607240
# 34     487  572.705511
# 40     587  744.366819
# 7      467  378.514735
# 10     580  422.279045
# 11     471  131.325863
# 31     554  712.614476
# 33     628  781.282121
# 27     631  643.747549
# 47     524  444.415758
# 2      561  639.918751
# 46     610  783.634240
# 18     865  874.777028
# 15     635  575.148214
# 28     574  541.003652
# 22     464  234.136725
# 16     603  605.544084
# 41     699  799.749905
# 20     649  730.917544
# 42     632  747.259853
# 8      464  355.912485
# 13     508  583.188766
# 25     566  531.947348
# 5      457  188.277925
# 17     714  720.341273
# 35     644  878.357406
# 14     566  662.957376
# 38     648  892.160345
# 1      524  576.743875
# 12     525  500.580921
# 43     591  684.600413
# 24     460  442.259337
# 6      344  -80.299427
# 23     547  350.368175
# ...

# %% [markdown]
# Задача: Экспериментально получены N − значений величины Y при
# различных значениях величины X. Построить полиномы первой и второй
# степени, аппроксимирующие результаты эксперимента, с применением
# метода наименьших квадратов. Результаты выводятся в виде таблиц
# значений и графиков, полученных полиномов.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Variant 
x = np.array([4.0, 4.2, 4.4, 4.6, 4.8, 5.0])
y = np.array([4.0, 3.0, 6.0, 6.0, 4.0, 4.0])

A = np.vstack([x, np.ones(len(x))]).T
print(A)

m, c = np.linalg.lstsq(A, y, rcond = None)[0]
print(m, c)

plt.plot(x, y, 'o', label = 'Исходные данные', markersize = 10)
plt.plot(x, m*x + c, 'r', label = 'Линейная экстраполяция')
plt.legend()
plt.show()

m = np.vstack((x ** 2, x, np.ones(6))).T

s = np.linalg.lstsq(m, y, rcond = None)[0]

x_prec = np.linspace(4, 5, 6)

plt.plot(x, y, 'D')
plt.plot(x_prec, s[0] * x_prec ** 2 + s[1] * x_prec + s[2], '-', lw = 2)
plt.grid()
print(s)
# Out:
# [[4.  1. ]
#  [4.2 1. ]
#  [4.4 1. ]
#  [4.6 1. ]
#  [4.8 1. ]
#  [5.  1. ]]
# 0.42857142857142755 2.5714285714285756
# [  -6.69642857   60.69642857 -132.25      ]
